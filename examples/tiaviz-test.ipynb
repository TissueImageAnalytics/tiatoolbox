# %%
from tiatoolbox.wsicore.wsireader import WSIReader
from tiatoolbox.visualization.tileserver import TileServer
from tiatoolbox.cli.visualize import run_bokeh
wsi = WSIReader.open("slides/sample_wsi.svs")
# app = TileServer(
#     title="Testing TileServer",
#     layers={
#         "My SVS": wsi,
#     },
# )
#app.run()

#run_bokeh([""], 5006, noshow=True)  # pragma: no cover

# %%
from tiatoolbox.models.engine.general_segmentor import GeneralSegmentor
from tiatoolbox.models.architecture.sam import SAM, SAMPrompts

abc = GeneralSegmentor(model=SAM())
prompts = SAMPrompts([100,100])
abc.predict(wsi, prompts, "cpu", "abcdefg")
# Out:
# |2025-01-30|18:05:59.141| [INFO] Loaded checkpoint sucessfully
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 abc = GeneralSegmentor(model=SAM())
#       5 prompts = SAMPrompts([100,100])
# ----> 6 abc.predict(wsi, prompts, "cpu", "abcdefg")
#
# File ~/cs310/tiatoolbox/tiatoolbox/models/engine/general_segmentor.py:116, in GeneralSegmentor.predict(self, file_name, prompts, device, save_path)
#     102 """Predict on a WSI using prompts.
#     103 Args:
#     104     file_name (str):
#    (...)
#     111         Location to save output prediction.
#     112 """
#     115 save_dir = _prepare_save_dir(save_dir=save_path)
# --> 116 wsi_save_dir = save_dir / "0.npy"
#     118 batch_data = self.load_wsi(file_name)
#     119 self.prediction = self.model.infer_batch(model=self.model, batch_data=batch_data, prompts=prompts, device=device)
#
# TypeError: unsupported operand type(s) for /: 'tuple' and 'str'
